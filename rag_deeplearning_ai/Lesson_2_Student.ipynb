# %% [markdown]
# # L2: Normalizing the Content

# %% [markdown]
# <p style="background-color:#fff6e4; padding:15px; border-width:3px; border-color:#f5ecda; border-style:solid; border-radius:6px"> ⏳ <b>Note <code>(Kernel Starting)</code>:</b> This notebook takes about 30 seconds to be ready to use. You may start and watch the video while you wait.</p>

# %%
# Warning control
import warnings

warnings.filterwarnings("ignore")

# %%
# !pip install unstructured_client
# !pip install "unstructured[docx,pptx]"
# Out:
# Requirement already satisfied: unstructured_client in /Users/aminehy/Documents/GitHub/webdata_collector/myenv/lib/python3.12/site-packages (0.22.0)
# Requirement already satisfied: certifi>=2023.7.22 in /Users/aminehy/Documents/GitHub/webdata_collector/myenv/lib/python3.12/site-packages (from unstructured_client) (2024.2.2)
# Requirement already satisfied: charset-normalizer>=3.2.0 in /Users/aminehy/Documents/GitHub/webdata_collector/myenv/lib/python3.12/site-packages (from unstructured_client) (3.3.2)
# Requirement already satisfied: dataclasses-json>=0.6.4 in /Users/aminehy/Documents/GitHub/webdata_collector/myenv/lib/python3.12/site-packages (from unstructured_client) (0.6.5)
# Requirement already satisfied: deepdiff>=6.0 in /Users/aminehy/Documents/GitHub/webdata_collector/myenv/lib/python3.12/site-packages (from unstructured_client) (7.0.1)
# Requirement already satisfied: idna>=3.4 in /Users/aminehy/Documents/GitHub/webdata_collector/myenv/lib/python3.12/site-packages (from unstructured_client) (3.7)
# Requirement already satisfied: jsonpath-python>=1.0.6 in /Users/aminehy/Documents/GitHub/webdata_collector/myenv/lib/python3.12/site-packages (from unstructured_client) (1.0.6)
# Requirement already satisfied: marshmallow>=3.19.0 in /Users/aminehy/Documents/GitHub/webdata_collector/myenv/lib/python3.12/site-packages (from unstructured_client) (3.21.2)
# Requirement already satisfied: mypy-extensions>=1.0.0 in /Users/aminehy/Documents/GitHub/webdata_collector/myenv/lib/python3.12/site-packages (from unstructured_client) (1.0.0)
# Requirement already satisfied: packaging>=23.1 in /Users/aminehy/Documents/GitHub/webdata_collector/myenv/lib/python3.12/site-packages (from unstructured_client) (23.2)
# Requirement already satisfied: pypdf>=4.0 in /Users/aminehy/Documents/GitHub/webdata_collector/myenv/lib/python3.12/site-packages (from unstructured_client) (4.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/aminehy/Documents/GitHub/webdata_collector/myenv/lib/python3.12/site-packages (from unstructured_client) (2.9.0.post0)
# Requirement already satisfied: requests>=2.31.0 in /Users/aminehy/Documents/GitHub/webdata_collector/myenv/lib/python3.12/site-packages (from unstructured_client) (2.31.0)
# Requirement already satisfied: six>=1.16.0 in /Users/aminehy/Documents/GitHub/webdata_collector/myenv/lib/python3.12/site-packages (from unstructured_client) (1.16.0)
# Requirement already satisfied: typing-inspect>=0.9.0 in /Users/aminehy/Documents/GitHub/webdata_collector/myenv/lib/python3.12/site-packages (from unstructured_client) (0.9.0)
# Requirement already satisfied: typing-extensions>=4.7.1 in /Users/aminehy/Documents/GitHub/webdata_collector/myenv/lib/python3.12/site-packages (from unstructured_client) (4.11.0)
# Requirement already satisfied: urllib3>=1.26.18 in /Users/aminehy/Documents/GitHub/webdata_collector/myenv/lib/python3.12/site-packages (from unstructured_client) (2.2.1)
# Requirement already satisfied: ordered-set<4.2.0,>=4.1.0 in /Users/aminehy/Documents/GitHub/webdata_collector/myenv/lib/python3.12/site-packages (from deepdiff>=6.0->unstructured_client) (4.1.0)
# Requirement already satisfied: unstructured[docx,pptx] in /Users/aminehy/Documents/GitHub/webdata_collector/myenv/lib/python3.12/site-packages (0.11.8)
# Requirement already satisfied: chardet in /Users/aminehy/Documents/GitHub/webdata_collector/myenv/lib/python3.12/site-packages (from unstructured[docx,pptx]) (5.2.0)
# Requirement already satisfied: filetype in /Users/aminehy/Documents/GitHub/webdata_collector/myenv/lib/python3.12/site-packages (from unstructured[docx,pptx]) (1.2.0)
# Requirement already satisfied: python-magic in /Users/aminehy/Documents/GitHub/webdata_collector/myenv/lib/python3.12/site-packages (from unstructured[docx,pptx]) (0.4.27)
# Requirement already satisfied: lxml in /Users/aminehy/Documents/GitHub/webdata_collector/myenv/lib/python3.12/site-packages (from unstructured[docx,pptx]) (5.2.1)
# Requirement already satisfied: nltk in /Users/aminehy/Documents/GitHub/webdata_collector/myenv/lib/python3.12/site-packages (from unstructured[docx,pptx]) (3.8.1)
# Requirement already satisfied: tabulate in /Users/aminehy/Documents/GitHub/webdata_collector/myenv/lib/python3.12/site-packages (from unstructured[docx,pptx]) (0.9.0)
# Requirement already satisfied: requests in /Users/aminehy/Documents/GitHub/webdata_collector/myenv/lib/python3.12/site-packages (from unstructured[docx,pptx]) (2.31.0)
# Requirement already satisfied: beautifulsoup4 in /Users/aminehy/Documents/GitHub/webdata_collector/myenv/lib/python3.12/site-packages (from unstructured[docx,pptx]) (4.12.2)
# Requirement already satisfied: emoji in /Users/aminehy/Documents/GitHub/webdata_collector/myenv/lib/python3.12/site-packages (from unstructured[docx,pptx]) (2.11.1)
# Requirement already satisfied: dataclasses-json in /Users/aminehy/Documents/GitHub/webdata_collector/myenv/lib/python3.12/site-packages (from unstructured[docx,pptx]) (0.6.5)
# Requirement already satisfied: python-iso639 in /Users/aminehy/Documents/GitHub/webdata_collector/myenv/lib/python3.12/site-packages (from unstructured[docx,pptx]) (2024.4.27)
# Requirement already satisfied: langdetect in /Users/aminehy/Documents/GitHub/webdata_collector/myenv/lib/python3.12/site-packages (from unstructured[docx,pptx]) (1.0.9)
# Requirement already satisfied: numpy in /Users/aminehy/Documents/GitHub/webdata_collector/myenv/lib/python3.12/site-packages (from unstructured[docx,pptx]) (1.26.4)
# Requirement already satisfied: rapidfuzz in /Users/aminehy/Documents/GitHub/webdata_collector/myenv/lib/python3.12/site-packages (from unstructured[docx,pptx]) (3.9.0)
# Requirement already satisfied: backoff in /Users/aminehy/Documents/GitHub/webdata_collector/myenv/lib/python3.12/site-packages (from unstructured[docx,pptx]) (2.2.1)
# Requirement already satisfied: typing-extensions in /Users/aminehy/Documents/GitHub/webdata_collector/myenv/lib/python3.12/site-packages (from unstructured[docx,pptx]) (4.11.0)
# Requirement already satisfied: unstructured-client in /Users/aminehy/Documents/GitHub/webdata_collector/myenv/lib/python3.12/site-packages (from unstructured[docx,pptx]) (0.22.0)
# Requirement already satisfied: wrapt in /Users/aminehy/Documents/GitHub/webdata_collector/myenv/lib/python3.12/site-packages (from unstructured[docx,pptx]) (1.16.0)
# Collecting python-docx>=1.1.0 (from unstructured[docx,pptx])
#   Downloading python_docx-1.1.2-py3-none-any.whl.metadata (2.0 kB)
# Collecting python-pptx<=0.6.23 (from unstructured[docx,pptx])
#   Downloading python_pptx-0.6.23-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: Pillow>=3.3.2 in /Users/aminehy/Documents/GitHub/webdata_collector/myenv/lib/python3.12/site-packages (from python-pptx<=0.6.23->unstructured[docx,pptx]) (10.2.0)
# Collecting XlsxWriter>=0.5.7 (from python-pptx<=0.6.23->unstructured[docx,pptx])
#   Downloading XlsxWriter-3.2.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: soupsieve>1.2 in /Users/aminehy/Documents/GitHub/webdata_collector/myenv/lib/python3.12/site-packages (from beautifulsoup4->unstructured[docx,pptx]) (2.5)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/aminehy/Documents/GitHub/webdata_collector/myenv/lib/python3.12/site-packages (from dataclasses-json->unstructured[docx,pptx]) (3.21.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/aminehy/Documents/GitHub/webdata_collector/myenv/lib/python3.12/site-packages (from dataclasses-json->unstructured[docx,pptx]) (0.9.0)
# Requirement already satisfied: six in /Users/aminehy/Documents/GitHub/webdata_collector/myenv/lib/python3.12/site-packages (from langdetect->unstructured[docx,pptx]) (1.16.0)
# Requirement already satisfied: click in /Users/aminehy/Documents/GitHub/webdata_collector/myenv/lib/python3.12/site-packages (from nltk->unstructured[docx,pptx]) (8.1.7)
# Requirement already satisfied: joblib in /Users/aminehy/Documents/GitHub/webdata_collector/myenv/lib/python3.12/site-packages (from nltk->unstructured[docx,pptx]) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /Users/aminehy/Documents/GitHub/webdata_collector/myenv/lib/python3.12/site-packages (from nltk->unstructured[docx,pptx]) (2024.5.10)
# Requirement already satisfied: tqdm in /Users/aminehy/Documents/GitHub/webdata_collector/myenv/lib/python3.12/site-packages (from nltk->unstructured[docx,pptx]) (4.66.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/aminehy/Documents/GitHub/webdata_collector/myenv/lib/python3.12/site-packages (from requests->unstructured[docx,pptx]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/aminehy/Documents/GitHub/webdata_collector/myenv/lib/python3.12/site-packages (from requests->unstructured[docx,pptx]) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/aminehy/Documents/GitHub/webdata_collector/myenv/lib/python3.12/site-packages (from requests->unstructured[docx,pptx]) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/aminehy/Documents/GitHub/webdata_collector/myenv/lib/python3.12/site-packages (from requests->unstructured[docx,pptx]) (2024.2.2)
# Requirement already satisfied: deepdiff>=6.0 in /Users/aminehy/Documents/GitHub/webdata_collector/myenv/lib/python3.12/site-packages (from unstructured-client->unstructured[docx,pptx]) (7.0.1)
# Requirement already satisfied: jsonpath-python>=1.0.6 in /Users/aminehy/Documents/GitHub/webdata_collector/myenv/lib/python3.12/site-packages (from unstructured-client->unstructured[docx,pptx]) (1.0.6)
# Requirement already satisfied: mypy-extensions>=1.0.0 in /Users/aminehy/Documents/GitHub/webdata_collector/myenv/lib/python3.12/site-packages (from unstructured-client->unstructured[docx,pptx]) (1.0.0)
# Requirement already satisfied: packaging>=23.1 in /Users/aminehy/Documents/GitHub/webdata_collector/myenv/lib/python3.12/site-packages (from unstructured-client->unstructured[docx,pptx]) (23.2)
# Requirement already satisfied: pypdf>=4.0 in /Users/aminehy/Documents/GitHub/webdata_collector/myenv/lib/python3.12/site-packages (from unstructured-client->unstructured[docx,pptx]) (4.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/aminehy/Documents/GitHub/webdata_collector/myenv/lib/python3.12/site-packages (from unstructured-client->unstructured[docx,pptx]) (2.9.0.post0)
# Requirement already satisfied: ordered-set<4.2.0,>=4.1.0 in /Users/aminehy/Documents/GitHub/webdata_collector/myenv/lib/python3.12/site-packages (from deepdiff>=6.0->unstructured-client->unstructured[docx,pptx]) (4.1.0)
# Downloading python_docx-1.1.2-py3-none-any.whl (244 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.3/244.3 kB 5.6 MB/s eta 0:00:00a 0:00:01
# Downloading python_pptx-0.6.23-py3-none-any.whl (471 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 471.6/471.6 kB 18.7 MB/s eta 0:00:00
# Downloading XlsxWriter-3.2.0-py3-none-any.whl (159 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.9/159.9 kB 18.2 MB/s eta 0:00:00
# Installing collected packages: XlsxWriter, python-docx, python-pptx
# Successfully installed XlsxWriter-3.2.0 python-docx-1.1.2 python-pptx-0.6.23

# %%
from IPython.display import JSON

import json

from unstructured_client import UnstructuredClient
from unstructured_client.models import shared
from unstructured_client.models.errors import SDKError

from unstructured.partition.html import partition_html
from unstructured.partition.pptx import partition_pptx
from unstructured.staging.base import dict_to_elements, elements_to_json

# %%
from Utils import Utils

utils = Utils()

DLAI_API_KEY = utils.get_dlai_api_key()
DLAI_API_URL = utils.get_dlai_url()

s = UnstructuredClient(
    api_key_auth=DLAI_API_KEY,
)

# %% [markdown]
# <p style="background-color:#fff6ff; padding:15px; border-width:3px; border-color:#efe6ef; border-style:solid; border-radius:6px"> 💻 &nbsp; <b>Access Utils File and Helper Functions:</b> To access helper functions and other related files for this notebook, 1) click on the <em>"View"</em> option on the top menu of the notebook and then 2) click on <em>"File Browser"</em>. For more help, please see the <em>"Appendix - Tips and Help"</em> Lesson.</p>

# %% [markdown]
# ## Example Document: Medium Blog HTML Page

# %%
filename = "../data/posts.html"
elements = partition_html(
    filename=filename,
)
# Out:
# INFO: Reading document from string ...
# INFO: Reading document ...

# %%
from rich import print

element_dict = [el.to_dict() for el in elements]
example_output = json.dumps(element_dict[11:15], indent=2)
print(element_dict)
# Out:
# [
#     {
#         'type': 'Title',
#         'element_id': 'd41f5b4977ee05c6b61b3b5f05478462',
#         'text': 'Facebook',
#         'metadata': {
#             'category_depth': 0,
#             'last_modified': '2024-05-12T21:49:17',
#             'link_texts': [None],
#             'link_urls': ['/'],
#             'page_number': 1,
#             'languages': ['eng'],
#             'file_directory': '../data',
#             'filename': 'posts.html',
#             'filetype': 'text/html'
#         }
#     },
#     {
#         'type': 'Title',
#         'element_id': '2ded4a3ee653ffdd82681e9f39144e16',
#         'text': 'Log In',
#         'metadata': {
#             'category_depth': 0,
#             'last_modified': '2024-05-12T21:49:17',
#             'emphasized_text_contents': ['Log In', 'Log In'],
#             'emphasized_text_tags': ['span', 'span'],
#             'link_texts': [None],
#             'link_urls': [
#                 'https://www.facebook.com/login/device-based/regular/login/?login_attempt=1&next=https%3A%2F%2Fwww.
# facebook.com%2Fmarketplace%2Fparis%2Fsearch%2F%3Fquery%3DMacbook%2520Pro%26maxPrice%3D1000%26itemCondition%3Dused_l
# ike_new%26exact%3Dtrue'
#             ],
#             'page_number': 1,
#             'languages': ['eng'],
#             'file_directory': '../data',
#             'filename': 'posts.html',
#             'filetype': 'text/html'
#         }
#     },
#     {
#         'type': 'Title',
#         'element_id': '2ded4a3ee653ffdd82681e9f39144e16',
#         'text': 'Log In',
#         'metadata': {
#             'category_depth': 0,
#             'last_modified': '2024-05-12T21:49:17',
#             'emphasized_text_contents': ['Log In', 'Log In'],
#             'emphasized_text_tags': ['span', 'span'],
#             'page_number': 1,
#             'languages': ['eng'],
#             'file_directory': '../data',
#             'filename': 'posts.html',
#             'filetype': 'text/html'
#         }
#     },
#     {
#         'type': 'Title',
#         'element_id': 'ab5ebd8aeab058e7327c5cb1e71b905d',
#         'text': 'Forgot Account?',
#         'metadata': {
#             'category_depth': 0,
#             'last_modified': '2024-05-12T21:49:17',
#             'emphasized_text_contents': ['Forgot Account?'],
#             'emphasized_text_tags': ['span'],
#             'link_texts': ['Forgot Account?'],
#             'link_urls': ['https://www.facebook.com/recover/initiate?ars=royal_blue_bar'],
#             'page_number': 1,
#             'languages': ['eng'],
#             'file_directory': '../data',
#             'filename': 'posts.html',
#             'filetype': 'text/html'
#         }
#     },
#     {
#         'type': 'Title',
#         'element_id': 'c608981d8d68fa4f7cc130ea31b77734',
#         'text': 'Marketplace',
#         'metadata': {
#             'category_depth': 0,
#             'last_modified': '2024-05-12T21:49:17',
#             'emphasized_text_contents': ['Marketplace', 'Marketplace'],
#             'emphasized_text_tags': ['span', 'span'],
#             'link_texts': ['Marketplace'],
#             'link_urls': ['/marketplace/'],
#             'page_number': 1,
#             'languages': ['eng'],
#             'file_directory': '../data',
#             'filename': 'posts.html',
#             'filetype': 'text/html'
#         }
#     },
#     {
#         'type': 'Title',
#         'element_id': 'e978b00de465a271a13bf2f6b9d74d67',
#         'text': 'Search results',
#         'metadata': {
#             'category_depth': 0,
#             'last_modified': '2024-05-12T21:49:17',
#             'emphasized_text_contents': ['Search results', 'Search results'],
#             'emphasized_text_tags': ['span', 'span'],
#             'page_number': 1,
#             'languages': ['eng'],
#             'file_directory': '../data',
#             'filename': 'posts.html',
#             'filetype': 'text/html'
#         }
#     },
#     {
#         'type': 'Title',
#         'element_id': 'ed6187fecbca2a65c671d7212aeebe89',
#         'text': 'Notify Me',
#         'metadata': {
#             'category_depth': 0,
#             'last_modified': '2024-05-12T21:49:17',
#             'emphasized_text_contents': ['Notify Me', 'Notify Me', 'Notify Me'],
#             'emphasized_text_tags': ['span', 'span', 'span'],
#             'page_number': 1,
#             'languages': ['eng'],
#             'file_directory': '../data',
#             'filename': 'posts.html',
#             'filetype': 'text/html'
#         }
#     },
#     {
#         'type': 'Title',
#         'element_id': '3ad1030f65785c1a8bf46331c5c7bc3d',
#         'text': 'Create new listing',
#         'metadata': {
#             'category_depth': 0,
#             'last_modified': '2024-05-12T21:49:17',
#             'emphasized_text_contents': ['Create new listing', 'Create new listing'],
#             'emphasized_text_tags': ['span', 'span'],
#             'link_texts': [None],
#             'link_urls': ['/marketplace/create/'],
#             'page_number': 1,
#             'languages': ['eng'],
#             'file_directory': '../data',
#             'filename': 'posts.html',
#             'filetype': 'text/html'
#         }
#     },
#     {
#         'type': 'Title',
#         'element_id': '546ebb8eb993ea561029d9febd84c363',
#         'text': 'Filters',
#         'metadata': {
#             'category_depth': 1,
#             'last_modified': '2024-05-12T21:49:17',
#             'emphasized_text_contents': ['Filters', 'Filters'],
#             'emphasized_text_tags': ['span', 'span'],
#             'page_number': 1,
#             'languages': ['eng'],
#             'parent_id': '3ad1030f65785c1a8bf46331c5c7bc3d',
#             'file_directory': '../data',
#             'filename': 'posts.html',
#             'filetype': 'text/html'
#         }
#     },
#     {
#         'type': 'UncategorizedText',
#         'element_id': 'd59a762f1d84f9158c8271906719743c',
#         'text': 'Paris, France\xa0\n                                                ·\n
# \n                                            Within 65 kilometers',
#         'metadata': {
#             'last_modified': '2024-05-12T21:49:17',
#             'emphasized_text_contents': [
#                 'Paris, France\xa0\n                                                ·\n
# \n                                            Within 65 kilometers',
#                 '·',
#                 '·'
#             ],
#             'emphasized_text_tags': ['span', 'span', 'span'],
#             'page_number': 1,
#             'languages': ['eng'],
#             'parent_id': '546ebb8eb993ea561029d9febd84c363',
#             'file_directory': '../data',
#             'filename': 'posts.html',
#             'filetype': 'text/html'
#         }
#     },
#     {
#         'type': 'Title',
#         'element_id': 'c9129025bd3ff6522a7eeebc1abf1481',
#         'text': 'Sort by',
#         'metadata': {
#             'category_depth': 0,
#             'last_modified': '2024-05-12T21:49:17',
#             'emphasized_text_contents': ['Sort by', 'Sort by'],
#             'emphasized_text_tags': ['span', 'span'],
#             'page_number': 1,
#             'languages': ['eng'],
#             'file_directory': '../data',
#             'filename': 'posts.html',
#             'filetype': 'text/html'
#         }
#     },
#     {
#         'type': 'Title',
#         'element_id': '93b63bab4c3a28d73a8bb83bcdfdcc5f',
#         'text': 'Suggested',
#         'metadata': {
#             'category_depth': 0,
#             'last_modified': '2024-05-12T21:49:17',
#             'emphasized_text_contents': ['Suggested'],
#             'emphasized_text_tags': ['span'],
#             'page_number': 1,
#             'languages': ['eng'],
#             'file_directory': '../data',
#             'filename': 'posts.html',
#             'filetype': 'text/html'
#         }
#     },
#     {
#         'type': 'UncategorizedText',
#         'element_id': '537c67e7c6649a2a1b9c7607f5248c1a',
#         'text': 'Distance: Nearest\n                                                              first',
#         'metadata': {
#             'last_modified': '2024-05-12T21:49:17',
#             'emphasized_text_contents': [
#                 'Distance: Nearest\n                                                              first'
#             ],
#             'emphasized_text_tags': ['span'],
#             'page_number': 1,
#             'languages': ['eng'],
#             'parent_id': '93b63bab4c3a28d73a8bb83bcdfdcc5f',
#             'file_directory': '../data',
#             'filename': 'posts.html',
#             'filetype': 'text/html'
#         }
#     },
#     {
#         'type': 'NarrativeText',
#         'element_id': '9dcfb5909c197550cfcf32f9accb2c7f',
#         'text': 'Date listed:\n                                                              Newest first',
#         'metadata': {
#             'last_modified': '2024-05-12T21:49:17',
#             'emphasized_text_contents': [
#                 'Date listed:\n                                                              Newest first'
#             ],
#             'emphasized_text_tags': ['span'],
#             'page_number': 1,
#             'languages': ['eng'],
#             'parent_id': '93b63bab4c3a28d73a8bb83bcdfdcc5f',
#             'file_directory': '../data',
#             'filename': 'posts.html',
#             'filetype': 'text/html'
#         }
#     },
#     {
#         'type': 'UncategorizedText',
#         'element_id': '3938055e097eb5c7085d53e4910da0d9',
#         'text': 'Price: Lowest\n                                                              first',
#         'metadata': {
#             'last_modified': '2024-05-12T21:49:17',
#             'emphasized_text_contents': [
#                 'Price: Lowest\n                                                              first'
#             ],
#             'emphasized_text_tags': ['span'],
#             'page_number': 1,
#             'languages': ['eng'],
#             'parent_id': '93b63bab4c3a28d73a8bb83bcdfdcc5f',
#             'file_directory': '../data',
#             'filename': 'posts.html',
#             'filetype': 'text/html'
#         }
#     },
#     {
#         'type': 'UncategorizedText',
#         'element_id': '76c12d4220ab13ac56f2413c541a381f',
#         'text': 'Price: Highest\n                                                              first',
#         'metadata': {
#             'last_modified': '2024-05-12T21:49:17',
#             'emphasized_text_contents': [
#                 'Price: Highest\n                                                              first'
#             ],
#             'emphasized_text_tags': ['span'],
#             'page_number': 1,
#             'languages': ['eng'],
#             'parent_id': '93b63bab4c3a28d73a8bb83bcdfdcc5f',
#             'file_directory': '../data',
#             'filename': 'posts.html',
#             'filetype': 'text/html'
#         }
#     },
#     {
#         'type': 'Title',
#         'element_id': '93c91c851e7acc17d881c9b89ea954be',
#         'text': 'Price',
#         'metadata': {
#             'category_depth': 0,
#             'last_modified': '2024-05-12T21:49:17',
#             'emphasized_text_contents': ['Price'],
#             'emphasized_text_tags': ['span'],
#             'page_number': 1,
#             'languages': ['eng'],
#             'file_directory': '../data',
#             'filename': 'posts.html',
#             'filetype': 'text/html'
#         }
#     },
#     {
#         'type': 'Title',
#         'element_id': '663ea1bfffe5038f3f0cf667f14c4257',
#         'text': 'to',
#         'metadata': {
#             'category_depth': 0,
#             'last_modified': '2024-05-12T21:49:17',
#             'emphasized_text_contents': ['to'],
#             'emphasized_text_tags': ['span'],
#             'page_number': 1,
#             'languages': ['eng'],
#             'file_directory': '../data',
#             'filename': 'posts.html',
#             'filetype': 'text/html'
#         }
#     },
#     {
#         'type': 'Title',
#         'element_id': '26b6ab1b68d5ad1cd555e816958ab729',
#         'text': 'Delivery method',
#         'metadata': {
#             'category_depth': 0,
#             'last_modified': '2024-05-12T21:49:17',
#             'emphasized_text_contents': ['Delivery method', 'Delivery method'],
#             'emphasized_text_tags': ['span', 'span'],
#             'page_number': 1,
#             'languages': ['eng'],
#             'file_directory': '../data',
#             'filename': 'posts.html',
#             'filetype': 'text/html'
#         }
#     },
#     {
#         'type': 'Title',
#         'element_id': 'a52ace420f2175d08b1577a1bea5445e',
#         'text': 'All',
#         'metadata': {
#             'category_depth': 0,
#             'last_modified': '2024-05-12T21:49:17',
#             'emphasized_text_contents': ['All'],
#             'emphasized_text_tags': ['span'],
#             'page_number': 1,
#             'languages': ['eng'],
#             'file_directory': '../data',
#             'filename': 'posts.html',
#             'filetype': 'text/html'
#         }
#     },
#     {
#         'type': 'UncategorizedText',
#         'element_id': '66477dc2e78fe63e46b5dc038f8a4814',
#         'text': 'Local\n                                                              pickup',
#         'metadata': {
#             'last_modified': '2024-05-12T21:49:17',
#             'emphasized_text_contents': [
#                 'Local\n                                                              pickup'
#             ],
#             'emphasized_text_tags': ['span'],
#             'page_number': 1,
#             'languages': ['eng'],
#             'parent_id': 'a52ace420f2175d08b1577a1bea5445e',
#             'file_directory': '../data',
#             'filename': 'posts.html',
#             'filetype': 'text/html'
#         }
#     },
#     {
#         'type': 'Title',
#         'element_id': 'ad5751430e295f0cec2699f46778f40b',
#         'text': 'Shipping',
#         'metadata': {
#             'category_depth': 0,
#             'last_modified': '2024-05-12T21:49:17',
#             'emphasized_text_contents': ['Shipping'],
#             'emphasized_text_tags': ['span'],
#             'page_number': 1,
#             'languages': ['eng'],
#             'file_directory': '../data',
#             'filename': 'posts.html',
#             'filetype': 'text/html'
#         }
#     },
#     {
#         'type': 'UncategorizedText',
#         'element_id': '471a61adabb984e4ec3599a6224d88bd',
#         'text': 'Condition: Used - Like\n                                                new',
#         'metadata': {
#             'last_modified': '2024-05-12T21:49:17',
#             'emphasized_text_contents': [
#                 'Condition: Used - Like\n                                                new',
#                 'Condition: Used - Like\n                                                new'
#             ],
#             'emphasized_text_tags': ['span', 'span'],
#             'page_number': 1,
#             'languages': ['eng'],
#             'parent_id': 'ad5751430e295f0cec2699f46778f40b',
#             'file_directory': '../data',
#             'filename': 'posts.html',
#             'filetype': 'text/html'
#         }
#     },
#     {
#         'type': 'Title',
#         'element_id': '83b12c2216efb4fdc924e1deb5182e90',
#         'text': 'Clear',
#         'metadata': {
#             'category_depth': 0,
#             'last_modified': '2024-05-12T21:49:17',
#             'emphasized_text_contents': ['Clear', 'Clear'],
#             'emphasized_text_tags': ['span', 'span'],
#             'page_number': 1,
#             'languages': ['eng'],
#             'file_directory': '../data',
#             'filename': 'posts.html',
#             'filetype': 'text/html'
#         }
#     },
#     {
#         'type': 'Title',
#         'element_id': '18fdd549b2ed367ac0c74cbec1214644',
#         'text': 'New',
#         'metadata': {
#             'category_depth': 0,
#             'last_modified': '2024-05-12T21:49:17',
#             'emphasized_text_contents': ['New'],
#             'emphasized_text_tags': ['span'],
#             'page_number': 1,
#             'languages': ['eng'],
#             'file_directory': '../data',
#             'filename': 'posts.html',
#             'filetype': 'text/html'
#         }
#     },
#     {
#         'type': 'UncategorizedText',
#         'element_id': '4f8a2a9d47085e1c6c87c03a2a565cb4',
#         'text': 'Used - Like\n                                                              new',
#         'metadata': {
#             'last_modified': '2024-05-12T21:49:17',
#             'emphasized_text_contents': [
#                 'Used - Like\n                                                              new'
#             ],
#             'emphasized_text_tags': ['span'],
#             'page_number': 1,
#             'languages': ['eng'],
#             'parent_id': '18fdd549b2ed367ac0c74cbec1214644',
#             'file_directory': '../data',
#             'filename': 'posts.html',
#             'filetype': 'text/html'
#         }
#     },
#     {
#         'type': 'Title',
#         'element_id': '0fd0d4189b5aa6fe1457204c2c2e4c28',
#         'text': 'Used - Good',
#         'metadata': {
#             'category_depth': 0,
#             'last_modified': '2024-05-12T21:49:17',
#             'emphasized_text_contents': ['Used - Good'],
#             'emphasized_text_tags': ['span'],
#             'page_number': 1,
#             'languages': ['eng'],
#             'file_directory': '../data',
#             'filename': 'posts.html',
#             'filetype': 'text/html'
#         }
#     },
#     {
#         'type': 'Title',
#         'element_id': '524f2464f522e8659e667c4cb93b305f',
#         'text': 'Used - Fair',
#         'metadata': {
#             'category_depth': 0,
#             'last_modified': '2024-05-12T21:49:17',
#             'emphasized_text_contents': ['Used - Fair'],
#             'emphasized_text_tags': ['span'],
#             'page_number': 1,
#             'languages': ['eng'],
#             'file_directory': '../data',
#             'filename': 'posts.html',
#             'filetype': 'text/html'
#         }
#     },
#     {
#         'type': 'NarrativeText',
#         'element_id': 'b7aedc139312ca22da8ffa08b655de17',
#         'text': 'Date listed',
#         'metadata': {
#             'last_modified': '2024-05-12T21:49:17',
#             'emphasized_text_contents': ['Date listed', 'Date listed'],
#             'emphasized_text_tags': ['span', 'span'],
#             'page_number': 1,
#             'languages': ['eng'],
#             'parent_id': '524f2464f522e8659e667c4cb93b305f',
#             'file_directory': '../data',
#             'filename': 'posts.html',
#             'filetype': 'text/html'
#         }
#     },
#     {
#         'type': 'Title',
#         'element_id': 'a52ace420f2175d08b1577a1bea5445e',
#         'text': 'All',
#         'metadata': {
#             'category_depth': 0,
#             'last_modified': '2024-05-12T21:49:17',
#             'emphasized_text_contents': ['All'],
#             'emphasized_text_tags': ['span'],
#             'page_number': 1,
#             'languages': ['eng'],
#             'file_directory': '../data',
#             'filename': 'posts.html',
#             'filetype': 'text/html'
#         }
#     },
#     {
#         'type': 'UncategorizedText',
#         'element_id': '0e51246a22c68f2f804726105a8f051f',
#         'text': 'Last 24\n                                                              hours',
#         'metadata': {
#             'last_modified': '2024-05-12T21:49:17',
#             'emphasized_text_contents': [
#                 'Last 24\n                                                              hours'
#             ],
#             'emphasized_text_tags': ['span'],
#             'page_number': 1,
#             'languages': ['eng'],
#             'parent_id': 'a52ace420f2175d08b1577a1bea5445e',
#             'file_directory': '../data',
#             'filename': 'posts.html',
#             'filetype': 'text/html'
#         }
#     },
#     {
#         'type': 'Title',
#         'element_id': '0603deca4fcb660f1c06a02621423721',
#         'text': 'Last 7 days',
#         'metadata': {
#             'category_depth': 0,
#             'last_modified': '2024-05-12T21:49:17',
#             'emphasized_text_contents': ['Last 7 days'],
#             'emphasized_text_tags': ['span'],
#             'page_number': 1,
#             'languages': ['eng'],
#             'file_directory': '../data',
#             'filename': 'posts.html',
#             'filetype': 'text/html'
#         }
#     },
#     {
#         'type': 'UncategorizedText',
#         'element_id': 'cdcd2c57278615f88704f98f235a7b6d',
#         'text': 'Last 30\n                                                              days',
#         'metadata': {
#             'last_modified': '2024-05-12T21:49:17',
#             'emphasized_text_contents': [
#                 'Last 30\n                                                              days'
#             ],
#             'emphasized_text_tags': ['span'],
#             'page_number': 1,
#             'languages': ['eng'],
#             'parent_id': '0603deca4fcb660f1c06a02621423721',
#             'file_directory': '../data',
#             'filename': 'posts.html',
#             'filetype': 'text/html'
#         }
#     },
#     {
#         'type': 'Title',
#         'element_id': '12f67f8539c46701e62d1c50254cf025',
#         'text': 'Availability',
#         'metadata': {
#             'category_depth': 0,
#             'last_modified': '2024-05-12T21:49:17',
#             'emphasized_text_contents': ['Availability', 'Availability'],
#             'emphasized_text_tags': ['span', 'span'],
#             'page_number': 1,
#             'languages': ['eng'],
#             'file_directory': '../data',
#             'filename': 'posts.html',
#             'filetype': 'text/html'
#         }
#     },
#     {
#         'type': 'Title',
#         'element_id': 'e674447337e83c1346f6122ed69f35bf',
#         'text': 'Available',
#         'metadata': {
#             'category_depth': 0,
#             'last_modified': '2024-05-12T21:49:17',
#             'emphasized_text_contents': ['Available'],
#             'emphasized_text_tags': ['span'],
#             'page_number': 1,
#             'languages': ['eng'],
#             'file_directory': '../data',
#             'filename': 'posts.html',
#             'filetype': 'text/html'
#         }
#     },
#     {
#         'type': 'Title',
#         'element_id': 'b870b1b48724de514d08b9c2a633a26d',
#         'text': 'Sold',
#         'metadata': {
#             'category_depth': 0,
#             'last_modified': '2024-05-12T21:49:17',
#             'emphasized_text_contents': ['Sold'],
#             'emphasized_text_tags': ['span'],
#             'page_number': 1,
#             'languages': ['eng'],
#             'file_directory': '../data',
#             'filename': 'posts.html',
#             'filetype': 'text/html'
#         }
#     },
#     {
#         'type': 'Title',
#         'element_id': 'b8b1d894c683725260dcd78f8ed64f97',
#         'text': 'Categories',
#         'metadata': {
#             'category_depth': 0,
#             'last_modified': '2024-05-12T21:49:17',
#             'emphasized_text_contents': ['Categories', 'Categories'],
#             'emphasized_text_tags': ['span', 'span'],
#             'page_number': 1,
#             'languages': ['eng'],
#             'file_directory': '../data',
#             'filename': 'posts.html',
#             'filetype': 'text/html'
#         }
#     },
#     {
#         'type': 'Title',
#         'element_id': '9113796a52c0df37c55b39646ac339d9',
#         'text': 'Vehicles',
#         'metadata': {
#             'category_depth': 0,
#             'last_modified': '2024-05-12T21:49:17',
#             'emphasized_text_contents': ['Vehicles'],
#             'emphasized_text_tags': ['span'],
#             'link_texts': [None],
#             'link_urls': ['/marketplace/paris/vehicles/'],
#             'page_number': 1,
#             'languages': ['eng'],
#             'file_directory': '../data',
#             'filename': 'posts.html',
#             'filetype': 'text/html'
#         }
#     },
#     {
#         'type': 'Title',
#         'element_id': '14c75d5605df99b5421a2f77a5cc9167',
#         'text': 'Property Rentals',
#         'metadata': {
#             'category_depth': 0,
#             'last_modified': '2024-05-12T21:49:17',
#             'emphasized_text_contents': ['Property Rentals'],
#             'emphasized_text_tags': ['span'],
#             'link_texts': [None],
#             'link_urls': ['/marketplace/paris/propertyrentals/'],
#             'page_number': 1,
#             'languages': ['eng'],
#             'file_directory': '../data',
#             'filename': 'posts.html',
#             'filetype': 'text/html'
#         }
#     },
#     {
#         'type': 'Title',
#         'element_id': '78d9b7366b7bd815cb6519e25c959214',
#         'text': 'Apparel',
#         'metadata': {
#             'category_depth': 0,
#             'last_modified': '2024-05-12T21:49:17',
#             'emphasized_text_contents': ['Apparel'],
#             'emphasized_text_tags': ['span'],
#             'link_texts': [None],
#             'link_urls': ['/marketplace/paris/apparel/'],
#             'page_number': 1,
#             'languages': ['eng'],
#             'file_directory': '../data',
#             'filename': 'posts.html',
#             'filetype': 'text/html'
#         }
#     },
#     {
#         'type': 'Title',
#         'element_id': 'c2a15c2c550a91eda017b1b3a454e211',
#         'text': 'Classifieds',
#         'metadata': {
#             'category_depth': 0,
#             'last_modified': '2024-05-12T21:49:17',
#             'emphasized_text_contents': ['Classifieds'],
#             'emphasized_text_tags': ['span'],
#             'link_texts': [None],
#             'link_urls': ['/marketplace/paris/classifieds/'],
#             'page_number': 1,
#             'languages': ['eng'],
#             'file_directory': '../data',
#             'filename': 'posts.html',
#             'filetype': 'text/html'
#         }
#     },
#     {
#         'type': 'Title',
#         'element_id': '7ae9c23d6592818270a3e5210b194d5d',
#         'text': 'Electronics',
#         'metadata': {
#             'category_depth': 0,
#             'last_modified': '2024-05-12T21:49:17',
#             'emphasized_text_contents': ['Electronics'],
#             'emphasized_text_tags': ['span'],
#             'link_texts': [None],
#             'link_urls': ['/marketplace/paris/electronics/'],
#             'page_number': 1,
#             'languages': ['eng'],
#             'file_directory': '../data',
#             'filename': 'posts.html',
#             'filetype': 'text/html'
#         }
#     },
#     {
#         'type': 'Title',
#         'element_id': 'ceaa553e838fb9f12e3e473ec6a8fe0c',
#         'text': 'Entertainment',
#         'metadata': {
#             'category_depth': 0,
#             'last_modified': '2024-05-12T21:49:17',
#             'emphasized_text_contents': ['Entertainment'],
#             'emphasized_text_tags': ['span'],
#             'link_texts': [None],
#             'link_urls': ['/marketplace/paris/entertainment/'],
#             'page_number': 1,
#             'languages': ['eng'],
#             'file_directory': '../data',
#             'filename': 'posts.html',
#             'filetype': 'text/html'
#         }
#     },
#     {
#         'type': 'Title',
#         'element_id': 'bd2d677b2ed4381b48bb1d0841052c6d',
#         'text': 'Family',
#         'metadata': {
#             'category_depth': 0,
#             'last_modified': '2024-05-12T21:49:17',
#             'emphasized_text_contents': ['Family'],
#             'emphasized_text_tags': ['span'],
#             'link_texts': [None],
#             'link_urls': ['/marketplace/paris/family/'],
#             'page_number': 1,
#             'languages': ['eng'],
#             'file_directory': '../data',
#             'filename': 'posts.html',
#             'filetype': 'text/html'
#         }
#     },
#     {
#         'type': 'Title',
#         'element_id': 'f669b46f6cc0bd5c14dc38a8de888aa9',
#         'text': 'Free Stuff',
#         'metadata': {
#             'category_depth': 0,
#             'last_modified': '2024-05-12T21:49:17',
#             'emphasized_text_contents': ['Free Stuff'],
#             'emphasized_text_tags': ['span'],
#             'link_texts': [None],
#             'link_urls': ['/marketplace/paris/free/'],
#             'page_number': 1,
#             'languages': ['eng'],
#             'file_directory': '../data',
#             'filename': 'posts.html',
#             'filetype': 'text/html'
#         }
#     },
#     {
#         'type': 'Title',
#         'element_id': 'd9b9c5691580ab03ad98ade3cd6923ad',
#         'text': 'Garden & Outdoor',
#         'metadata': {
#             'category_depth': 0,
#             'last_modified': '2024-05-12T21:49:17',
#             'emphasized_text_contents': ['Garden & Outdoor'],
#             'emphasized_text_tags': ['span'],
#             'link_texts': [None],
#             'link_urls': ['/marketplace/paris/garden/'],
#             'page_number': 1,
#             'languages': ['eng'],
#             'file_directory': '../data',
#             'filename': 'posts.html',
#             'filetype': 'text/html'
#         }
#     },
#     {
#         'type': 'Title',
#         'element_id': '2a6f4ac627084bc788578d863f909a2d',
#         'text': 'Hobbies',
#         'metadata': {
#             'category_depth': 0,
#             'last_modified': '2024-05-12T21:49:17',
#             'emphasized_text_contents': ['Hobbies'],
#             'emphasized_text_tags': ['span'],
#             'link_texts': [None],
#             'link_urls': ['/marketplace/paris/hobbies/'],
#             'page_number': 1,
#             'languages': ['eng'],
#             'file_directory': '../data',
#             'filename': 'posts.html',
#             'filetype': 'text/html'
#         }
#     },
#     {
#         'type': 'Title',
#         'element_id': 'f634f77f8be3a72371ef27eea3f29e3f',
#         'text': 'Home Goods',
#         'metadata': {
#             'category_depth': 0,
#             'last_modified': '2024-05-12T21:49:17',
#             'emphasized_text_contents': ['Home Goods'],
#             'emphasized_text_tags': ['span'],
#             'link_texts': [None],
#             'link_urls': ['/marketplace/paris/home/'],
#             'page_number': 1,
#             'languages': ['eng'],
#             'file_directory': '../data',
#             'filename': 'posts.html',
#             'filetype': 'text/html'
#         }
#     },
#     {
#         'type': 'UncategorizedText',
#         'element_id': '03c100a39561e7781094bf1fb4522355',
#         'text': 'Home Improvement\n                                                    Supplies',
#         'metadata': {
#             'last_modified': '2024-05-12T21:49:17',
#             'emphasized_text_contents': [
#                 'Home Improvement\n                                                    Supplies'
#             ],
#             'emphasized_text_tags': ['span'],
#             'link_texts': [None],
#             'link_urls': ['/marketplace/paris/home-improvements/'],
#             'page_number': 1,
#             'languages': ['eng'],
#             'parent_id': 'f634f77f8be3a72371ef27eea3f29e3f',
#             'file_directory': '../data',
#             'filename': 'posts.html',
#             'filetype': 'text/html'
#         }
#     },
#     {
#         'type': 'Title',
#         'element_id': 'a13ccd0771c8c3cd204756210703ab07',
#         'text': 'Home Sales',
#         'metadata': {
#             'category_depth': 0,
#             'last_modified': '2024-05-12T21:49:17',
#             'emphasized_text_contents': ['Home Sales'],
#             'emphasized_text_tags': ['span'],
#             'link_texts': [None],
#             'link_urls': ['/marketplace/paris/propertyforsale/'],
#             'page_number': 1,
#             'languages': ['eng'],
#             'file_directory': '../data',
#             'filename': 'posts.html',
#             'filetype': 'text/html'
#         }
#     },
#     {
#         'type': 'Title',
#         'element_id': 'c351bed536d6194b832647a72b4a09bf',
#         'text': 'Musical Instruments',
#         'metadata': {
#             'category_depth': 0,
#             'last_modified': '2024-05-12T21:49:17',
#             'emphasized_text_contents': ['Musical Instruments'],
#             'emphasized_text_tags': ['span'],
#             'link_texts': [None],
#             'link_urls': ['/marketplace/paris/instruments/'],
#             'page_number': 1,
#             'languages': ['eng'],
#             'file_directory': '../data',
#             'filename': 'posts.html',
#             'filetype': 'text/html'
#         }
#     },
#     {
#         'type': 'Title',
#         'element_id': '1ddddcf46d352c118117b2ca446bbd39',
#         'text': 'Office Supplies',
#         'metadata': {
#             'category_depth': 0,
#             'last_modified': '2024-05-12T21:49:17',
#             'emphasized_text_contents': ['Office Supplies'],
#             'emphasized_text_tags': ['span'],
#             'link_texts': [None],
#             'link_urls': ['/marketplace/paris/office-supplies/'],
#             'page_number': 1,
#             'languages': ['eng'],
#             'file_directory': '../data',
#             'filename': 'posts.html',
#             'filetype': 'text/html'
#         }
#     },
#     {
#         'type': 'Title',
#         'element_id': '708c28088976d7c192b9a1c4fd25aa10',
#         'text': 'Pet Supplies',
#         'metadata': {
#             'category_depth': 0,
#             'last_modified': '2024-05-12T21:49:17',
#             'emphasized_text_contents': ['Pet Supplies'],
#             'emphasized_text_tags': ['span'],
#             'link_texts': [None],
#             'link_urls': ['/marketplace/paris/pets/'],
#             'page_number': 1,
#             'languages': ['eng'],
#             'file_directory': '../data',
#             'filename': 'posts.html',
#             'filetype': 'text/html'
#         }
#     },
#     {
#         'type': 'Title',
#         'element_id': '7507438a82655a0496177f852fec5f2e',
#         'text': 'Sporting Goods',
#         'metadata': {
#             'category_depth': 0,
#             'last_modified': '2024-05-12T21:49:17',
#             'emphasized_text_contents': ['Sporting Goods'],
#             'emphasized_text_tags': ['span'],
#             'link_texts': [None],
#             'link_urls': ['/marketplace/paris/sports/'],
#             'page_number': 1,
#             'languages': ['eng'],
#             'file_directory': '../data',
#             'filename': 'posts.html',
#             'filetype': 'text/html'
#         }
#     },
#     {
#         'type': 'Title',
#         'element_id': '257907b53ef6d19eaf223a682c48e726',
#         'text': 'Toys & Games',
#         'metadata': {
#             'category_depth': 0,
#             'last_modified': '2024-05-12T21:49:17',
#             'emphasized_text_contents': ['Toys & Games'],
#             'emphasized_text_tags': ['span'],
#             'link_texts': [None],
#             'link_urls': ['/marketplace/paris/toys/'],
#             'page_number': 1,
#             'languages': ['eng'],
#             'file_directory': '../data',
#             'filename': 'posts.html',
#             'filetype': 'text/html'
#         }
#     },
#     {
#         'type': 'Title',
#         'element_id': '0faf530c0add2d015b5c1842a9549b9b',
#         'text': 'More categories',
#         'metadata': {
#             'category_depth': 0,
#             'last_modified': '2024-05-12T21:49:17',
#             'emphasized_text_contents': ['More categories'],
#             'emphasized_text_tags': ['span'],
#             'link_texts': [None],
#             'link_urls': ['/marketplace/categories/'],
#             'page_number': 1,
#             'languages': ['eng'],
#             'file_directory': '../data',
#             'filename': 'posts.html',
#             'filetype': 'text/html'
#         }
#     },
#     {
#         'type': 'NarrativeText',
#         'element_id': 'b2ffad7139344fa2773ad3b0d911faf9',
#         'text': 'Paris · 65 km',
#         'metadata': {
#             'last_modified': '2024-05-12T21:49:17',
#             'emphasized_text_contents': ['Paris · 65 km', 'Paris · 65 km'],
#             'emphasized_text_tags': ['span', 'span'],
#             'page_number': 1,
#             'languages': ['eng'],
#             'parent_id': '0faf530c0add2d015b5c1842a9549b9b',
#             'file_directory': '../data',
#             'filename': 'posts.html',
#             'filetype': 'text/html'
#         }
#     },
#     {
#         'type': 'Title',
#         'element_id': '546ebb8eb993ea561029d9febd84c363',
#         'text': 'Filters',
#         'metadata': {
#             'category_depth': 0,
#             'last_modified': '2024-05-12T21:49:17',
#             'emphasized_text_contents': ['Filters', 'Filters'],
#             'emphasized_text_tags': ['span', 'span'],
#             'page_number': 1,
#             'languages': ['eng'],
#             'file_directory': '../data',
#             'filename': 'posts.html',
#             'filetype': 'text/html'
#         }
#     },
#     {
#         'type': 'Title',
#         'element_id': 'ed6187fecbca2a65c671d7212aeebe89',
#         'text': 'Notify Me',
#         'metadata': {
#             'category_depth': 0,
#             'last_modified': '2024-05-12T21:49:17',
#             'emphasized_text_contents': ['Notify Me', 'Notify Me', 'Notify Me'],
#             'emphasized_text_tags': ['span', 'span', 'span'],
#             'page_number': 1,
#             'languages': ['eng'],
#             'file_directory': '../data',
#             'filename': 'posts.html',
#             'filetype': 'text/html'
#         }
#     },
#     {
#         'type': 'UncategorizedText',
#         'element_id': '4cf89c3a7fb608cfc5ec243293fa8431',
#         'text': '€200\n                                                        \n
# \n                                                    \n                                                      \n
# MacBook Pro\n                                                              URGENT\n
# \n                                                    \n                                                    \n
# \n                                                          Paris, IDF',
#         'metadata': {
#             'last_modified': '2024-05-12T21:49:17',
#             'emphasized_text_contents': [
#                 '€200\n                                                        \n
# \n                                                    \n                                                      \n
# MacBook Pro\n                                                              URGENT\n
# \n                                                    \n                                                    \n
# \n                                                          Paris, IDF',
#                 '€200',
#                 '€200',
#                 'MacBook Pro\n                                                              URGENT',
#                 'MacBook Pro\n                                                              URGENT',
#                 'MacBook Pro\n                                                              URGENT',
#                 'Paris, IDF',
#                 'Paris, IDF',
#                 'Paris, IDF'
#             ],
#             'emphasized_text_tags': ['span', 'span', 'span', 'span', 'span', 'span', 'span', 'span', 'span'],
#             'link_texts': [None],
#             'link_urls': [
#                 '/marketplace/item/1927362054385880/?ref=search&referral_code=null&referral_story_type=post&__tn__=
# !%3AD'
#             ],
#             'page_number': 1,
#             'languages': ['eng'],
#             'parent_id': 'ed6187fecbca2a65c671d7212aeebe89',
#             'file_directory': '../data',
#             'filename': 'posts.html',
#             'filetype': 'text/html'
#         }
#     },
#     {
#         'type': 'UncategorizedText',
#         'element_id': '9ff6112998381f7210fe0c1590d454c0',
#         'text': '€850\n                                                        \n
# \n                                                    \n                                                      \n
# MacBook Pro 15’\n                                                              1To\n
# \n                                                    \n                                                    \n
# \n                                                          Éragny, IDF',
#         'metadata': {
#             'last_modified': '2024-05-12T21:49:17',
#             'emphasized_text_contents': [
#                 '€850\n                                                        \n
# \n                                                    \n                                                      \n
# MacBook Pro 15’\n                                                              1To\n
# \n                                                    \n                                                    \n
# \n                                                          Éragny, IDF',
#                 '€850',
#                 '€850',
#                 'MacBook Pro 15’\n                                                              1To',
#                 'MacBook Pro 15’\n                                                              1To',
#                 'MacBook Pro 15’\n                                                              1To',
#                 'Éragny, IDF',
#                 'Éragny, IDF',
#                 'Éragny, IDF'
#             ],
#             'emphasized_text_tags': ['span', 'span', 'span', 'span', 'span', 'span', 'span', 'span', 'span'],
#             'link_texts': [None],
#             'link_urls': [
#                 '/marketplace/item/435208939203770/?ref=search&referral_code=null&referral_story_type=post&__tn__=!
# %3AD'
#             ],
#             'page_number': 1,
#             'languages': ['eng'],
#             'parent_id': 'ed6187fecbca2a65c671d7212aeebe89',
#             'file_directory': '../data',
#             'filename': 'posts.html',
#             'filetype': 'text/html'
#         }
#     },
#     {
#         'type': 'UncategorizedText',
#         'element_id': 'dd0819ee1d1bcd6685c6598c9c8ed279',
#         'text': '€150\n                                                        \n
# \n                                                    \n                                                      \n
# MacBook Pro 8Go\n                                                              Ram\n
# \n                                                    \n                                                    \n
# \n                                                          Paris, IDF',
#         'metadata': {
#             'last_modified': '2024-05-12T21:49:17',
#             'emphasized_text_contents': [
#                 '€150\n                                                        \n
# \n                                                    \n                                                      \n
# MacBook Pro 8Go\n                                                              Ram\n
# \n                                                    \n                                                    \n
# \n                                                          Paris, IDF',
#                 '€150',
#                 '€150',
#                 'MacBook Pro 8Go\n                                                              Ram',
#                 'MacBook Pro 8Go\n                                                              Ram',
#                 'MacBook Pro 8Go\n                                                              Ram',
#                 'Paris, IDF',
#                 'Paris, IDF',
#                 'Paris, IDF'
#             ],
#             'emphasized_text_tags': ['span', 'span', 'span', 'span', 'span', 'span', 'span', 'span', 'span'],
#             'link_texts': [None],
#             'link_urls': [
#                 '/marketplace/item/1458670464732147/?ref=search&referral_code=null&referral_story_type=post&__tn__=
# !%3AD'
#             ],
#             'page_number': 1,
#             'languages': ['eng'],
#             'parent_id': 'ed6187fecbca2a65c671d7212aeebe89',
#             'file_directory': '../data',
#             'filename': 'posts.html',
#             'filetype': 'text/html'
#         }
#     },
#     {
#         'type': 'UncategorizedText',
#         'element_id': '32200f420a4c77b33b63886cb5aa09ed',
#         'text': '€430€480\n                                                        \n
# \n                                                    \n                                                      \n
# MacBook Pro\n                                                              (2018)\n
# \n                                                    \n                                                    \n
# \n                                                          Paris, IDF',
#         'metadata': {
#             'last_modified': '2024-05-12T21:49:17',
#             'emphasized_text_contents': [
#                 '€430€480\n                                                        \n
# \n                                                    \n                                                      \n
# MacBook Pro\n                                                              (2018)\n
# \n                                                    \n                                                    \n
# \n                                                          Paris, IDF',
#                 '€430€480',
#                 '€430',
#                 '€480',
#                 '€480',
#                 'MacBook Pro\n                                                              (2018)',
#                 'MacBook Pro\n                                                              (2018)',
#                 'MacBook Pro\n                                                              (2018)',
#                 'Paris, IDF',
#                 'Paris, IDF',
#                 'Paris, IDF'
#             ],
#             'emphasized_text_tags': [
#                 'span',
#                 'span',
#                 'span',
#                 'span',
#                 'span',
#                 'span',
#                 'span',
#                 'span',
#                 'span',
#                 'span',
#                 'span'
#             ],
#             'link_texts': [None],
#             'link_urls': [
#                 '/marketplace/item/1142347326801225/?ref=search&referral_code=null&referral_story_type=post&__tn__=
# !%3AD'
#             ],
#             'page_number': 1,
#             'languages': ['eng'],
#             'parent_id': 'ed6187fecbca2a65c671d7212aeebe89',
#             'file_directory': '../data',
#             'filename': 'posts.html',
#             'filetype': 'text/html'
#         }
#     },
#     {
#         'type': 'UncategorizedText',
#         'element_id': '2e969dc127eb1f2a869a4c4ef30d15ca',
#         'text': '€120\n                                                        \n
# \n                                                    \n                                                      \n
# MacBook en\n                                                              parfait état\n
# \n                                                    \n                                                    \n
# \n                                                          Paris, IDF',
#         'metadata': {
#             'last_modified': '2024-05-12T21:49:17',
#             'emphasized_text_contents': [
#                 '€120\n                                                        \n
# \n                                                    \n                                                      \n
# MacBook en\n                                                              parfait état\n
# \n                                                    \n                                                    \n
# \n                                                          Paris, IDF',
#                 '€120',
#                 '€120',
#                 'MacBook en\n                                                              parfait état',
#                 'MacBook en\n                                                              parfait état',
#                 'MacBook en\n                                                              parfait état',
#                 'Paris, IDF',
#                 'Paris, IDF',
#                 'Paris, IDF'
#             ],
#             'emphasized_text_tags': ['span', 'span', 'span', 'span', 'span', 'span', 'span', 'span', 'span'],
#             'link_texts': [None],
#             'link_urls': [
# ...
#             ],
#             'emphasized_text_tags': ['span', 'span', 'span', 'span', 'span', 'span', 'span', 'span', 'span'],
#             'link_texts': [None],
#             'link_urls': [
#                 '/marketplace/item/1052923215936749/?ref=search&referral_code=null&referral_story_type=post&__tn__=
# !%3AD'
#             ],
#             'page_number': 1,
#             'languages': ['eng'],
#             'parent_id': 'ed6187fecbca2a65c671d7212aeebe89',
#             'file_directory': '../data',
#             'filename': 'posts.html',
#             'filetype': 'text/html'
#         }
#     },
#     {
#         'type': 'UncategorizedText',
#         'element_id': 'a46a4245ca7062d978ad4f12c083f107',
#         'text': '€750\n                                                        \n
# \n                                                    \n                                                      \n
# MacBook Air\n                                                              2019\n
# \n                                                    \n                                                    \n
# \n                                                          Paris, IDF',
#         'metadata': {
#             'last_modified': '2024-05-12T21:49:17',
#             'emphasized_text_contents': [
#                 '€750\n                                                        \n
# \n                                                    \n                                                      \n
# MacBook Air\n                                                              2019\n
# \n                                                    \n                                                    \n
# \n                                                          Paris, IDF',
#                 '€750',
#                 '€750',
#                 'MacBook Air\n                                                              2019',
#                 'MacBook Air\n                                                              2019',
#                 'MacBook Air\n                                                              2019',
#                 'Paris, IDF',
#                 'Paris, IDF',
#                 'Paris, IDF'
#             ],
#             'emphasized_text_tags': ['span', 'span', 'span', 'span', 'span', 'span', 'span', 'span', 'span'],
#             'link_texts': [None],
#             'link_urls': [
#                 '/marketplace/item/758667849582786/?ref=search&referral_code=null&referral_story_type=post&__tn__=!
# %3AD'
#             ],
#             'page_number': 1,
#             'languages': ['eng'],
#             'parent_id': 'ed6187fecbca2a65c671d7212aeebe89',
#             'file_directory': '../data',
#             'filename': 'posts.html',
#             'filetype': 'text/html'
#         }
#     },
#     {
#         'type': 'UncategorizedText',
#         'element_id': '0377b4bc52a306885793e6d31c9c1341',
#         'text': '€200\n                                                        \n
# \n                                                    \n                                                      \n
# MacBook Pro\n                                                        \n
# \n                                                    \n                                                      \n
# Paris, IDF',
#         'metadata': {
#             'last_modified': '2024-05-12T21:49:17',
#             'emphasized_text_contents': [
#                 '€200\n                                                        \n
# \n                                                    \n                                                      \n
# MacBook Pro\n                                                        \n
# \n                                                    \n                                                      \n
# Paris, IDF',
#                 '€200',
#                 '€200',
#                 'MacBook Pro',
#                 'MacBook Pro',
#                 'MacBook Pro',
#                 'Paris, IDF',
#                 'Paris, IDF',
#                 'Paris, IDF'
#             ],
#             'emphasized_text_tags': ['span', 'span', 'span', 'span', 'span', 'span', 'span', 'span', 'span'],
#             'link_texts': [None],
#             'link_urls': [
#                 '/marketplace/item/1640320323374222/?ref=search&referral_code=null&referral_story_type=post&__tn__=
# !%3AD'
#             ],
#             'page_number': 1,
#             'languages': ['eng'],
#             'parent_id': 'ed6187fecbca2a65c671d7212aeebe89',
#             'file_directory': '../data',
#             'filename': 'posts.html',
#             'filetype': 'text/html'
#         }
#     },
#     {
#         'type': 'UncategorizedText',
#         'element_id': '0377b4bc52a306885793e6d31c9c1341',
#         'text': '€200\n                                                        \n
# \n                                                    \n                                                      \n
# MacBook Pro\n                                                        \n
# \n                                                    \n                                                      \n
# Paris, IDF',
#         'metadata': {
#             'last_modified': '2024-05-12T21:49:17',
#             'emphasized_text_contents': [
#                 '€200\n                                                        \n
# \n                                                    \n                                                      \n
# MacBook Pro\n                                                        \n
# \n                                                    \n                                                      \n
# Paris, IDF',
#                 '€200',
#                 '€200',
#                 'MacBook Pro',
#                 'MacBook Pro',
#                 'MacBook Pro',
#                 'Paris, IDF',
#                 'Paris, IDF',
#                 'Paris, IDF'
#             ],
#             'emphasized_text_tags': ['span', 'span', 'span', 'span', 'span', 'span', 'span', 'span', 'span'],
#             'link_texts': [None],
#             'link_urls': [
#                 '/marketplace/item/3694756657438758/?ref=search&referral_code=null&referral_story_type=post&__tn__=
# !%3AD'
#             ],
#             'page_number': 1,
#             'languages': ['eng'],
#             'parent_id': 'ed6187fecbca2a65c671d7212aeebe89',
#             'file_directory': '../data',
#             'filename': 'posts.html',
#             'filetype': 'text/html'
#         }
#     },
#     {
#         'type': 'UncategorizedText',
#         'element_id': '42f03b5b81444e3948da89f3a7c2cb99',
#         'text': '€800\n                                                        \n
# \n                                                    \n                                                      \n
# MacBook pro\n                                                              14\n
# \n                                                    \n                                                    \n
# \n                                                          Paris, IDF',
#         'metadata': {
#             'last_modified': '2024-05-12T21:49:17',
#             'emphasized_text_contents': [
#                 '€800\n                                                        \n
# \n                                                    \n                                                      \n
# MacBook pro\n                                                              14\n
# \n                                                    \n                                                    \n
# \n                                                          Paris, IDF',
#                 '€800',
#                 '€800',
#                 'MacBook pro\n                                                              14',
#                 'MacBook pro\n                                                              14',
#                 'MacBook pro\n                                                              14',
#                 'Paris, IDF',
#                 'Paris, IDF',
#                 'Paris, IDF'
#             ],
#             'emphasized_text_tags': ['span', 'span', 'span', 'span', 'span', 'span', 'span', 'span', 'span'],
#             'link_texts': [None],
#             'link_urls': [
#                 '/marketplace/item/424449790344928/?ref=search&referral_code=null&referral_story_type=post&__tn__=!
# %3AD'
#             ],
#             'page_number': 1,
#             'languages': ['eng'],
#             'parent_id': 'ed6187fecbca2a65c671d7212aeebe89',
#             'file_directory': '../data',
#             'filename': 'posts.html',
#             'filetype': 'text/html'
#         }
#     },
#     {
#         'type': 'UncategorizedText',
#         'element_id': '26a95dafb05ce4c6b2fca061f80a6a0a',
#         'text': '€600\n                                                        \n
# \n                                                    \n                                                      \n
# MacBook Pro\n                                                              2021\n
# \n                                                    \n                                                    \n
# \n                                                          Paris, IDF',
#         'metadata': {
#             'last_modified': '2024-05-12T21:49:17',
#             'emphasized_text_contents': [
#                 '€600\n                                                        \n
# \n                                                    \n                                                      \n
# MacBook Pro\n                                                              2021\n
# \n                                                    \n                                                    \n
# \n                                                          Paris, IDF',
#                 '€600',
#                 '€600',
#                 'MacBook Pro\n                                                              2021',
#                 'MacBook Pro\n                                                              2021',
#                 'MacBook Pro\n                                                              2021',
#                 'Paris, IDF',
#                 'Paris, IDF',
#                 'Paris, IDF'
#             ],
#             'emphasized_text_tags': ['span', 'span', 'span', 'span', 'span', 'span', 'span', 'span', 'span'],
#             'link_texts': [None],
#             'link_urls': [
#                 '/marketplace/item/1634065157396611/?ref=search&referral_code=null&referral_story_type=post&__tn__=
# !%3AD'
#             ],
#             'page_number': 1,
#             'languages': ['eng'],
#             'parent_id': 'ed6187fecbca2a65c671d7212aeebe89',
#             'file_directory': '../data',
#             'filename': 'posts.html',
#             'filetype': 'text/html'
#         }
#     },
#     {
#         'type': 'NarrativeText',
#         'element_id': '3ba22a95b4af681f8889148a72d8a3c4',
#         'text': 'See more on Facebook',
#         'metadata': {
#             'last_modified': '2024-05-12T21:49:17',
#             'emphasized_text_contents': ['See more on Facebook', 'See more on Facebook'],
#             'emphasized_text_tags': ['span', 'span'],
#             'page_number': 1,
#             'languages': ['eng'],
#             'parent_id': 'ed6187fecbca2a65c671d7212aeebe89',
#             'file_directory': '../data',
#             'filename': 'posts.html',
#             'filetype': 'text/html'
#         }
#     },
#     {
#         'type': 'NarrativeText',
#         'element_id': '3ba22a95b4af681f8889148a72d8a3c4',
#         'text': 'See more on Facebook',
#         'metadata': {
#             'last_modified': '2024-05-12T21:49:17',
#             'emphasized_text_contents': ['See more on Facebook'],
#             'emphasized_text_tags': ['span'],
#             'page_number': 1,
#             'languages': ['eng'],
#             'parent_id': 'ed6187fecbca2a65c671d7212aeebe89',
#             'file_directory': '../data',
#             'filename': 'posts.html',
#             'filetype': 'text/html'
#         }
#     },
#     {
#         'type': 'Title',
#         'element_id': 'deab68a05f90d1728f69f43322c77184',
#         'text': 'Email or phone number',
#         'metadata': {
#             'category_depth': 0,
#             'last_modified': '2024-05-12T21:49:17',
#             'emphasized_text_contents': ['Email or phone number'],
#             'emphasized_text_tags': ['span'],
#             'page_number': 1,
#             'languages': ['eng'],
#             'file_directory': '../data',
#             'filename': 'posts.html',
#             'filetype': 'text/html'
#         }
#     },
#     {
#         'type': 'Title',
#         'element_id': 'e7cf3ef4f17c3999a94f2c6f612e8a88',
#         'text': 'Password',
#         'metadata': {
#             'category_depth': 0,
#             'last_modified': '2024-05-12T21:49:17',
#             'emphasized_text_contents': ['Password'],
#             'emphasized_text_tags': ['span'],
#             'page_number': 1,
#             'languages': ['eng'],
#             'file_directory': '../data',
#             'filename': 'posts.html',
#             'filetype': 'text/html'
#         }
#     },
#     {
#         'type': 'Title',
#         'element_id': '2ded4a3ee653ffdd82681e9f39144e16',
#         'text': 'Log In',
#         'metadata': {
#             'category_depth': 0,
#             'last_modified': '2024-05-12T21:49:17',
#             'emphasized_text_contents': ['Log In', 'Log In'],
#             'emphasized_text_tags': ['span', 'span'],
#             'page_number': 1,
#             'languages': ['eng'],
#             'file_directory': '../data',
#             'filename': 'posts.html',
#             'filetype': 'text/html'
#         }
#     },
#     {
#         'type': 'Title',
#         'element_id': '30c1d8d3e912889307433b5fec7c012f',
#         'text': 'Forgot password?',
#         'metadata': {
#             'category_depth': 0,
#             'last_modified': '2024-05-12T21:49:17',
#             'emphasized_text_contents': ['Forgot password?'],
#             'emphasized_text_tags': ['span'],
#             'link_texts': [None],
#             'link_urls': ['https://www.facebook.com/recover/initiate?ars=royal_blue_bar'],
#             'page_number': 1,
#             'languages': ['eng'],
#             'file_directory': '../data',
#             'filename': 'posts.html',
#             'filetype': 'text/html'
#         }
#     },
#     {
#         'type': 'Title',
#         'element_id': '7175517a370b5cd2e664e3fd29c4ea9d',
#         'text': 'or',
#         'metadata': {
#             'category_depth': 0,
#             'last_modified': '2024-05-12T21:49:17',
#             'emphasized_text_contents': ['or'],
#             'emphasized_text_tags': ['span'],
#             'page_number': 1,
#             'languages': ['eng'],
#             'file_directory': '../data',
#             'filename': 'posts.html',
#             'filetype': 'text/html'
#         }
#     },
#     {
#         'type': 'Title',
#         'element_id': 'ff864de1f62ef87bfb802e2a90e82071',
#         'text': 'Create new account',
#         'metadata': {
#             'category_depth': 0,
#             'last_modified': '2024-05-12T21:49:17',
#             'emphasized_text_contents': ['Create new account', 'Create new account'],
#             'emphasized_text_tags': ['span', 'span'],
#             'page_number': 1,
#             'languages': ['eng'],
#             'file_directory': '../data',
#             'filename': 'posts.html',
#             'filetype': 'text/html'
#         }
#     }
# ]

# %%
JSON(example_output)

# %% [markdown]
# ## Example Doc: MSFT PowerPoint on OpenAI

# %%
Image(filename="images/pptx_slide.png", height=600, width=600)

# %%
filename = "example_files/msft_openai.pptx"
elements = partition_pptx(filename=filename)

# %%
element_dict = [el.to_dict() for el in elements]
JSON(json.dumps(element_dict[:], indent=2))

# %% [markdown]
# ## Example Document: PDF on Chain-of-Thought

# %%
Image(filename="images/cot_paper.png", height=600, width=600)

# %%
filename = "example_files/CoT.pdf"
with open(filename, "rb") as f:
    files = shared.Files(
        content=f.read(),
        file_name=filename,
    )

req = shared.PartitionParameters(
    files=files,
    strategy="hi_res",
    pdf_infer_table_structure=True,
    languages=["eng"],
)
try:
    resp = s.general.partition(req)
    print(json.dumps(resp.elements[:3], indent=2))
except SDKError as e:
    print(e)

# %%
JSON(json.dumps(resp.elements, indent=2))

# %% [markdown]
# ## Work With Your Own Files

# %%
import panel as pn

# import param
from Utils import upld_file

pn.extension()

# %%
upld_widget = upld_file()
pn.Row(upld_widget.widget_file_upload)

# %% [markdown]
# <p style="background-color:#fff6e4; padding:15px; border-width:3px; border-color:#f5ecda; border-style:solid; border-radius:6px"> 🖥 &nbsp; <b>Note:</b> If the file upload interface isn't functioning properly, the issue may be related to your browser version. In such a case, please ensure your browser is updated to the latest version, or try using a different browser.</p>

# %%
# !ls ./example_files

# %% [markdown]
# <p style="background-color:#fff6ff; padding:15px; border-width:3px; border-color:#efe6ef; border-style:solid; border-radius:6px"> 💻 &nbsp; <b>Uploading Your Own File - Method 2:</b> To upload your own files, you can also 1) click on the <em>"View"</em> option on the top menu of the notebook and then 2) click on <em>"File Browser"</em>. Then 3) click on <em>"Upload"</em> button to upload your files. For more help, please see the <em>"Appendix - Tips and Help"</em> Lesson.</p>
